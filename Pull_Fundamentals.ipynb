# %%
#Import all our modules and libraries 

import pandas as pd
import yfinance as yf
import time
from alpha_vantage.timeseries import TimeSeries
import requests
from datetime import datetime
from datetime import timedelta
import plotly.graph_objects as go
from pathlib import Path
import hvplot.pandas

# %%
#Create function to pull data from Alphavantage

def pull_alpha_data(function, ticker): 

    base_url = 'https://www.alphavantage.co/query?'
    params = {'function': function,
             'symbol': ticker,
             'apikey': '0GTFFL66G1VMDZJ5'}

    response = requests.get(base_url, params=params)
    data = response.json()
    return data

# %%
#Pull data from yfinance 

ticker_df = {}

td = timedelta(730)
end_date = datetime.now()
start_date = end_date - td

user_tickers = input("Enter the symbbols of the stock you wish to analyze seperated by a comma: i.e SPY, AAPL, TSLA")
user_tickers = user_tickers.split(', ')

short_ticker_list = user_tickers

short_ticker_list.append('SPY')

print(short_ticker_list)

#for loop for iterating through ticker list
for ticker in short_ticker_list:
    print(f'Checking Data for Ticker {ticker}')
    #statement for continuing loop in the case of an error from Yahoo Finance Package & getting ticker symbol data
    try: 
        data_df = yf.download(ticker, start=start_date, end=end_date)
        data_df['ticker'] = ticker
        data_df.reset_index(inplace=True)
        #Include the header on the 1st file write 
        if short_ticker_list.index(ticker) == 0:
            mode = None
            header = True
        #ignoring header on subsequent writes
        else:
            mode = 'a'
            header = False
        #writing dataframe to csv
        data_df.to_csv('project_ticker_data.csv',mode='a',header=header)
        time.sleep(2)
        
    except:
        print(f'Data for ticker: {ticker} is not available')
        pass
# Out:
# Enter the symbbols of the stock you wish to analyze seperated by a comma: i.e SPY, AAPL, TSLA TSLA,  TDOC,  ROKU,  SQ,  SHOP,  ZM,  SPOT,  Z,  TWLO,  COIN,  U,  EXAS,  CRSP,  DOCU,  PLTR,  NVTA,  TXG,  NTLA,  DKNG,  NTDOY,  BEAM,  SE,  IRDM,  IOVA,  TWTR,  FATE,  TCEHY,  TER,  TWOU,  TWST,  PRLB,  PATH,  PD,  SKLZ,  PSTG,  ICE,  BEKE,  EDIT,  NVS,  TSP,  VCYT,  BLI,  MCRB,  PACB,  MTLS,  TRMB,  NSTG,  SSYS,  CERS
# ['TSLA', ' TDOC', ' ROKU', ' SQ', ' SHOP', ' ZM', ' SPOT', ' Z', ' TWLO', ' COIN', ' U', ' EXAS', ' CRSP', ' DOCU', ' PLTR', ' NVTA', ' TXG', ' NTLA', ' DKNG', ' NTDOY', ' BEAM', ' SE', ' IRDM', ' IOVA', ' TWTR', ' FATE', ' TCEHY', ' TER', ' TWOU', ' TWST', ' PRLB', ' PATH', ' PD', ' SKLZ', ' PSTG', ' ICE', ' BEKE', ' EDIT', ' NVS', ' TSP', ' VCYT', ' BLI', ' MCRB', ' PACB', ' MTLS', ' TRMB', ' NSTG', ' SSYS', ' CERS ', 'SPY']
# Checking Data for Ticker TSLA
# [*********************100%***********************]  1 of 1 completed
# Data for ticker: TSLA is not available
# Checking Data for Ticker  TDOC
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TDOC is not available
# Checking Data for Ticker  ROKU
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  ROKU is not available
# Checking Data for Ticker  SQ
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SQ is not available
# Checking Data for Ticker  SHOP
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SHOP is not available
# Checking Data for Ticker  ZM
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  ZM is not available
# Checking Data for Ticker  SPOT
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SPOT is not available
# Checking Data for Ticker  Z
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  Z is not available
# Checking Data for Ticker  TWLO
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TWLO is not available
# Checking Data for Ticker  COIN
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  COIN is not available
# Checking Data for Ticker  U
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  U is not available
# Checking Data for Ticker  EXAS
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  EXAS is not available
# Checking Data for Ticker  CRSP
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  CRSP is not available
# Checking Data for Ticker  DOCU
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  DOCU is not available
# Checking Data for Ticker  PLTR
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PLTR is not available
# Checking Data for Ticker  NVTA
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  NVTA is not available
# Checking Data for Ticker  TXG
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TXG is not available
# Checking Data for Ticker  NTLA
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  NTLA is not available
# Checking Data for Ticker  DKNG
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  DKNG is not available
# Checking Data for Ticker  NTDOY
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  NTDOY is not available
# Checking Data for Ticker  BEAM
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  BEAM is not available
# Checking Data for Ticker  SE
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SE is not available
# Checking Data for Ticker  IRDM
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  IRDM is not available
# Checking Data for Ticker  IOVA
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  IOVA is not available
# Checking Data for Ticker  TWTR
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TWTR is not available
# Checking Data for Ticker  FATE
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  FATE is not available
# Checking Data for Ticker  TCEHY
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TCEHY is not available
# Checking Data for Ticker  TER
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TER is not available
# Checking Data for Ticker  TWOU
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TWOU is not available
# Checking Data for Ticker  TWST
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TWST is not available
# Checking Data for Ticker  PRLB
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PRLB is not available
# Checking Data for Ticker  PATH
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PATH is not available
# Checking Data for Ticker  PD
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PD is not available
# Checking Data for Ticker  SKLZ
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SKLZ is not available
# Checking Data for Ticker  PSTG
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PSTG is not available
# Checking Data for Ticker  ICE
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  ICE is not available
# Checking Data for Ticker  BEKE
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  BEKE is not available
# Checking Data for Ticker  EDIT
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  EDIT is not available
# Checking Data for Ticker  NVS
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  NVS is not available
# Checking Data for Ticker  TSP
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TSP is not available
# Checking Data for Ticker  VCYT
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  VCYT is not available
# Checking Data for Ticker  BLI
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  BLI is not available
# Checking Data for Ticker  MCRB
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  MCRB is not available
# Checking Data for Ticker  PACB
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  PACB is not available
# Checking Data for Ticker  MTLS
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  MTLS is not available
# Checking Data for Ticker  TRMB
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  TRMB is not available
# Checking Data for Ticker  NSTG
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  NSTG is not available
# Checking Data for Ticker  SSYS
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  SSYS is not available
# Checking Data for Ticker  CERS
# [*********************100%***********************]  1 of 1 completed
# Data for ticker:  CERS  is not available
# Checking Data for Ticker SPY
# [*********************100%***********************]  1 of 1 completed
# Data for ticker: SPY is not available

# %%
#Pull second set of data from alphavantage
for ticker in short_ticker_list:
    print(f'Checking Data for Ticker {ticker}')
    #statement for continuing loop in the case of an error from Yahoo Finance Package & getting ticker symbol data
    try:
        data_df_2 = pull_alpha_data('OVERVIEW', ticker)
        data_df_df = pd.DataFrame([data_df_2])
        data_df_df['ticker'] = ticker     
        data_df_df.reset_index(inplace=True)
        #Include the header on the 1st file write 

        #print(short_ticker_list.index(ticker))    
        #input('Hold')

        if short_ticker_list.index(ticker) == 0:
            mode = 'w'
            header = True
        #ignoring header on subsequent writes
        else:
            mode = 'a'
            header = False
        #writing dataframe to csv
        
        data_df_df.to_csv('project_ticker_data_2.csv',mode=mode, header=header)
    
        time.sleep(15)
        
    except:
        print(f'Data for ticker: {ticker} is not available')
        pass
# Out:
# Checking Data for Ticker TSLA
# Checking Data for Ticker  TDOC
# Checking Data for Ticker  ROKU
# Checking Data for Ticker  SQ
# Checking Data for Ticker  SHOP
# Checking Data for Ticker  ZM
# Checking Data for Ticker  SPOT
# Checking Data for Ticker  Z
# Checking Data for Ticker  TWLO
# Checking Data for Ticker  COIN
# Checking Data for Ticker  U
# Checking Data for Ticker  EXAS
# Checking Data for Ticker  CRSP
# Checking Data for Ticker  DOCU
# Checking Data for Ticker  PLTR
# Checking Data for Ticker  NVTA
# Checking Data for Ticker  TXG
# Checking Data for Ticker  NTLA
# Checking Data for Ticker  DKNG
# Checking Data for Ticker  NTDOY
# Checking Data for Ticker  BEAM
# Checking Data for Ticker  SE
# Checking Data for Ticker  IRDM
# Checking Data for Ticker  IOVA
# Checking Data for Ticker  TWTR
# Checking Data for Ticker  FATE
# Checking Data for Ticker  TCEHY
# Checking Data for Ticker  TER
# Checking Data for Ticker  TWOU

# %%
# Read in and clean data

project_1 = pd.read_csv('project_ticker_data.csv')
project_2 = pd.read_csv('project_ticker_data_2.csv')

project_1.set_index('ticker',inplace=True)
project_1.drop(columns=['Unnamed: 0'],inplace=True)

project_2.set_index('ticker',inplace=True)
project_2.drop(columns=['Unnamed: 0'],inplace=True)

# %%
clean_data = project_1[[ 'Date', 'Open', 'High', 'Low', 'Close', 'Volume']]
clean_data.tail()

# %%
project_2

# %%
clean_data_2 = project_2[['QuarterlyEarningsGrowthYOY', 'QuarterlyRevenueGrowthYOY', 'ProfitMargin',
                          '52WeekHigh', '52WeekLow', 'Beta', 'EPS', '50DayMovingAverage', '200DayMovingAverage', 'AnalystTargetPrice']]



clean_data_2.head()

# %%
#joining cleaned data into a single csv

new_data = clean_data.join(clean_data_2, how='outer', on=clean_data.index)
new_data.dropna(inplace=True)
new_data.drop(columns='key_0', inplace=True)
#new_data.drop(axis=0, index='ticker', inplace=True)
new_data.index.name = 'Ticker'
new_data['Close'] = new_data['Close'].astype("float")
new_data["MADelta"] = new_data["50DayMovingAverage"] - new_data["200DayMovingAverage"]
new_data["52wkhighpercent"] = new_data["Close"] / (new_data["52WeekHigh"])
new_data["52wklowpercent"] = new_data["Close"] / (new_data["52WeekLow"])

new_data.to_csv('join_data.csv')
print(new_data)

# %%
new_data['Close'] = new_data['Close'].astype("float")
new_data.dtypes
#type(new_data["52WeekHigh"])
#new_data["52wkhighpercent"] = new_data[["Close"]].div(new_data["52WeekHigh"])

#new_data["52wkhighpercent"] = new_data["Close"]/new_data["52WeekHigh"]

#new_data["52wkhighpercent"]
new_data['Close']

# %%
#create new data frames to make ploting information easier 

#read in dataframe
data_df = pd.read_csv(Path("join_data.csv"), index_col="Ticker")


#Creating dataframe with unique ticker row & information
summary_df = data_df.drop(columns=['Date'])
unique_sum_df = summary_df.reset_index().drop_duplicates(subset='Ticker',keep='first').set_index('Ticker')

#Plotting Top Earnings Growth YOY Companies
quart_earnings_df = unique_sum_df.sort_values('QuarterlyEarningsGrowthYOY',ascending=False)

#Creating Moving Average Delta DF
madelta_earnings_df = unique_sum_df.sort_values('MADelta', ascending=False)

#Creating 52 Wk High Percentage DF
yearhighpercentage_df = unique_sum_df.sort_values('52wkhighpercent', ascending=False)

#Creating 52 Wk Low Percentage DF
yearlowpercentage_df = unique_sum_df.sort_values('52wklowpercent', ascending=False)

#Creating beta DF
beta_df = unique_sum_df.sort_values('Beta', ascending=True)

top_earnings_df = quart_earnings_df.head(15)
#top_unique_df.head(10)
earnings_graph = top_earnings_df.hvplot.barh(x='Ticker', y='QuarterlyEarningsGrowthYOY',flip_yaxis=True)


#Plotting Top Earnings Per Share Companies
eps_df = unique_sum_df.sort_values('EPS',ascending=False)
top_eps_df = eps_df.head(15)
eps_graph = top_eps_df.hvplot.barh(x='Ticker', y='EPS',flip_yaxis=True)



#Plotting Top Profit Margin Sectors
pm_df = unique_sum_df.sort_values('ProfitMargin',ascending=False)
top_pm_df = pm_df.head(15)
#profit_margin_graph = top_pm_df.hvplot.barh(x='Sector', y='ProfitMargin',flip_yaxis=True)

#Plotting Top Quarterly Revenue Sectors
revenue_df = unique_sum_df.sort_values('QuarterlyRevenueGrowthYOY',ascending=False)
top_revenue_df = revenue_df.head(15)
revenue_graph = top_revenue_df.hvplot.barh(x='Ticker', y='QuarterlyRevenueGrowthYOY',flip_yaxis=True)

# %%
quart_earnings_df

# %%
top_revenue_df

# %%
madelta_earnings_df

# %%
pm_df

# %%
eps_df

# %%
yearhighpercentage_df

# %%
yearlowpercentage_df

# %%
beta_df

# %%
unique_sum_df

# %%
#Rank Stocks
fundamental_measures = unique_sum_df.loc[:,['QuarterlyEarningsGrowthYOY', 'QuarterlyRevenueGrowthYOY', 'ProfitMargin', 'EPS','MADelta', '52wkhighpercent', '52wklowpercent']]
ranked_stocks = fundamental_measures.rank(axis=0, ascending=True, method='dense').astype(int)
ranked_stocks['sum_total'] = (ranked_stocks['QuarterlyEarningsGrowthYOY'] * 0.15) + (ranked_stocks['QuarterlyRevenueGrowthYOY'] * 0.15) + (ranked_stocks['ProfitMargin'] * 0.15) + (ranked_stocks[ 'EPS'] * 0.1) +  (ranked_stocks[ 'MADelta'] * 0.25) +  (ranked_stocks['52wkhighpercent'] * 0.1) +  (ranked_stocks['52wklowpercent'] * 0.1)

# %%
ranked_stocks.sort_values('sum_total', ascending=False, inplace=True)
recommended_stocks = ranked_stocks.head(3)
print(recommended_stocks)
print(recommended_tickers)
